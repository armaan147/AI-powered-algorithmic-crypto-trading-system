# %% [markdown]
# # 1. Loading the data

# %%
import streamlit as st 
import ccxt
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import plotly.graph_objects as go 
from datetime import datetime,timedelta
from binance.client import Client 
from sklearn.linear_model import LinearRegression 
from PIL import Image

# %%
API_KEY = 'your_api_key'
API_SECRET = 'your_api_secret'

# %%
client = Client(API_KEY, API_SECRET, {"timeout": 2})

# %%
def fetch_crypto_data(symbol, interval, days=3):
  
    since = int((datetime.now() - timedelta(days=days)).timestamp() * 1000)
    candles = client.get_klines(symbol=symbol, interval=interval, startTime=since)
    df = pd.DataFrame(candles, columns=['timestamp', 'open', 'high', 'low', 'close', 'volume', 'close_time', 'quote_asset_volume', 'number_of_trades', 'taker_buy_base_asset_volume', 'taker_buy_quote_asset_volume', 'ignore'])
    df = df[['timestamp', 'open', 'high', 'low', 'close', 'volume']]
    df['timestamp'] = pd.to_datetime(df['timestamp'], unit='ms')
    df[['open', 'high', 'low', 'close', 'volume']] = df[['open', 'high', 'low', 'close', 'volume']].astype(float)
    return df

# %%
btc_df = fetch_crypto_data('BTCUSDT', "15m", days = 2)
btc_df
# Out:
#               timestamp      open      high       low     close     volume
# 0   2026-01-14 20:30:00  97338.51  97761.71  97327.05  97556.14  197.04221
# 1   2026-01-14 20:45:00  97556.14  97670.64  97390.01  97655.28  233.92934
# 2   2026-01-14 21:00:00  97655.27  97655.27  97437.20  97496.19  133.59681
# 3   2026-01-14 21:15:00  97496.20  97611.51  97459.13  97584.32   88.34967
# 4   2026-01-14 21:30:00  97584.31  97717.72  97507.27  97507.28  130.05618
# ..                  ...       ...       ...       ...       ...        ...
# 187 2026-01-16 19:15:00  94981.00  95000.95  94841.31  94861.39   45.92230
# 188 2026-01-16 19:30:00  94861.38  95055.31  94861.38  94948.47   37.08108
# 189 2026-01-16 19:45:00  94948.47  95040.43  94948.46  95002.09   32.39890
# 190 2026-01-16 20:00:00  95002.09  95002.10  94682.00  94880.54   83.36728
# 191 2026-01-16 20:15:00  94880.53  94893.27  94880.53  94893.26    1.17672
#
# [192 rows x 6 columns]
