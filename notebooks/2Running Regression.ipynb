# %% [markdown]
# # 2. Running Regression

# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression

# Load the data
btc_df = pd.read_csv('../data/processed/btcusdt_1h_with_signals.csv')

def calculate_regression(df):
    """Calculate regression analysis to determine trend."""
    X = np.arange(len(df)).reshape(-1, 1)
    y = df['close'].values
    model = LinearRegression()
    model.fit(X, y)
    y_pred = model.predict(X)
    slope = model.coef_[0]
    return 'Positive' if slope > 0 else 'Negative' if slope < 0 else 'Flat', y_pred

# %%
btc_trend, y_pred = calculate_regression(btc_df)
btc_trend
# Out:
# 'Positive'

# %%
y_pred
# Out:
# array([ 13326.02139978,  13329.98458371,  13333.94776765, ...,
#        117561.72207572, 117565.68525966, 117569.64844359], shape=(26304,))
